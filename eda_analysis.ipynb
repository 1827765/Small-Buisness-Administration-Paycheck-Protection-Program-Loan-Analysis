# %% [markdown]
# # EDA

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sms

# %matplotlib inline

pd.set_option('display.max.column', 55)

# %%
#Puling the data 

df = pd.read_csv('public_up_to_150k_12_230930.csv')

# %%
df
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9898628801   04/24/2021            304              PPS
# 1       5645658400   02/09/2021            304              PPS
# 2       6526737308   04/30/2020            304              PPP
# 3       2785097106   04/11/2020            304              PPP
# 4       3792067100   04/12/2020            304              PPP
# ...            ...          ...            ...              ...
# 599769  9160347307   05/01/2020            897              PPP
# 599770  8452318607   03/24/2021            897              PPP
# 599771  5991058901   05/01/2021            897              PPP
# 599772  6164058608   03/20/2021            897              PPP
# 599773  5170998610   03/20/2021            897              PPP
#
#                              BorrowerName     BorrowerAddress    BorrowerCity  \
# 0                   HALES RESTAURANT INC.     7643 Roanoke Rd      Shawsville
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599774 entries, 0 to 599773
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599774 non-null  int64
#  1   DateApproved                 599774 non-null  object
#  2   SBAOfficeCode                599774 non-null  int64
#  3   ProcessingMethod             599774 non-null  object
#  4   BorrowerName                 599766 non-null  object
#  5   BorrowerAddress              599768 non-null  object
#  6   BorrowerCity                 599769 non-null  object
#  7   BorrowerState                599774 non-null  object
#  8   BorrowerZip                  599769 non-null  object
#  9   LoanStatusDate               589994 non-null  object
#  10  LoanStatus                   599774 non-null  object
#  11  Term                         599774 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        8
# BorrowerAddress                     6
# BorrowerCity                        5
# BorrowerState                       0
# BorrowerZip                         5
# LoanStatusDate                   9780
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                 170
# FranchiseName                  591542
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# ...

# %%
df = df[df['BorrowerName'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599766 entries, 0 to 599773
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599766 non-null  int64
#  1   DateApproved                 599766 non-null  object
#  2   SBAOfficeCode                599766 non-null  int64
#  3   ProcessingMethod             599766 non-null  object
#  4   BorrowerName                 599766 non-null  object
#  5   BorrowerAddress              599760 non-null  object
#  6   BorrowerCity                 599761 non-null  object
#  7   BorrowerState                599766 non-null  object
#  8   BorrowerZip                  599761 non-null  object
#  9   LoanStatusDate               589986 non-null  object
#  10  LoanStatus                   599766 non-null  object
#  11  Term                         599766 non-null  int64
# ...

# %%
#Adding colums to allow fine tuned data analytics 

df['year_approved'] = pd.DatetimeIndex(df['DateApproved']).year
df['month_approved'] = pd.DatetimeIndex(df['DateApproved']).month

df['year_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).year
df['month_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).month
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13228\746049383.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_approved'] = pd.DatetimeIndex(df['DateApproved']).year
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13228\746049383.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_approved'] = pd.DatetimeIndex(df['DateApproved']).month
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13228\746049383.py:6: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9898628801   04/24/2021            304              PPS
# 1  5645658400   02/09/2021            304              PPS
# 2  6526737308   04/30/2020            304              PPP
# 3  2785097106   04/11/2020            304              PPP
# 4  3792067100   04/12/2020            304              PPP
#
#                         BorrowerName    BorrowerAddress    BorrowerCity  \
# 0              HALES RESTAURANT INC.    7643 Roanoke Rd      Shawsville
# 1            GREENWAY BAPTIST CHURCH     1275 Tasker Rd   Stephens City
# 2            LONDON BRIDGE MOTOR CO.  2409 BOWLAND PKWY  VIRGINIA BEACH
# 3  POWHATAN AUTO & TRACTOR PARTS INC  3350 Anderson Hwy        POWHATAN
# 4   MOLLY'S COCKLES AND MUSSELS, LLC       36 C MAIN ST       WARRENTON
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            VA       24162     08/05/2022  Paid in Full    60
# ...

# %%
FirstRound = df.loc[df['ProcessingMethod'] == 'PPP']

# %%
SecondRound = df.loc[df['ProcessingMethod'] == 'PPS']

# %%
SecondRound.head()
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0   9898628801   04/24/2021            304              PPS
# 1   5645658400   02/09/2021            304              PPS
# 7   1546078508   02/19/2021            304              PPS
# 9   2793418603   03/15/2021            353              PPS
# 10  2982618505   02/22/2021            304              PPS
#
#                     BorrowerName                  BorrowerAddress  \
# 0          HALES RESTAURANT INC.                  7643 Roanoke Rd
# 1        GREENWAY BAPTIST CHURCH                   1275 Tasker Rd
# 7   FINTEL FAMILY DENTISTRY PLLC             6220 Peters Creek Rd
# 9             UNITED STONES INC.  14 Bryant Court 14 Bryant Court
# 10          ERNESTINES TABLE LLC                   509 Halifax St
#
#      BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  \
# 0      Shawsville            VA       24162     08/05/2022  Paid in Full
# ...

# %% [markdown]
# ## Categorize Variables

# %% [markdown]
# ### Univariable

# %%
#count of records accorinf to payment rounds 

sms.countplot(df['ProcessingMethod'])
# Out:
# <Axes: xlabel='count', ylabel='ProcessingMethod'>

# %%
sms.countplot(df['Term'])
# Out:
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x0000026D8754F560> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x0000026D896AC9A0> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %%
sms.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
plt.figure(figsize=(15,6))
ax = sms.countplot(x = 'BusinessType', palette = "pink" ,data = df )
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13228\148763552.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sms.countplot(x = 'BusinessType', palette = "pink" ,data = df )
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13228\148763552.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %% [markdown]
# ## Bivaribale

# %%
## Plotting Ethincity against Laons

sms.countplot(x= 'Ethnicity', hue = 'LoanStatus', data = df )
# Out:
# <Axes: xlabel='Ethnicity', ylabel='count'>

# %%
##cross tabulation

pd.crosstab(df['Ethnicity'],df['BorrowerState'])
# Out:
# BorrowerState               VA    VI     VT      WA      WI     WV     WY
# Ethnicity
# Hispanic or Latino        2779   167     78    3695    1772    158    406
# Not Hispanic or Latino   39697   892   5042   40576   47981   9530   6121
# Unknown/NotStated       139342  2054  14309  127207  120709  20264  16987

# %%
pd.crosstab(df['year_approved'],df['BorrowerState'])
# Out:
# BorrowerState     VA    VI     VT     WA     WI     WV     WY
# year_approved
# 2020           86659  1864  10784  90870  76658  15687  12160
# 2021           95159  1249   8645  80608  93804  14265  11354

# %%
pd.crosstab(df['Ethnicity'],df['LoanStatus'])
# Out:
# LoanStatus              Charged Off  Exemption 4  Paid in Full
# Ethnicity
# Hispanic or Latino              265          227          8563
# Not Hispanic or Latino         3075         3351        143413
# Unknown/NotStated             16168         6202        418502

# %% [markdown]
# ### Numerical Variable - Discrete varibale

# %%
## descriptive variable 

df['CurrentApprovalAmount'].describe()
# Out:
# count    599766.000000
# mean      27240.760184
# std       28308.408789
# min           1.800000
# 25%        8600.000000
# 50%       19375.000000
# 75%       33300.000000
# max      149999.990000
# Name: CurrentApprovalAmount, dtype: float64

# %% [markdown]
# ### Outliers

# %%
sms.boxplot(x = df['CurrentApprovalAmount'])
# Out:
# <Axes: xlabel='CurrentApprovalAmount'>

# %%
plt.figure(figsize=(14,5))
sms.boxplot(x = 'LoanStatus', y = 'CurrentApprovalAmount', data= df)
# Out:
# <Axes: xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %%
sms.distplot(df['CurrentApprovalAmount']/10 ** 5)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13228\66908650.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sms.distplot(df['CurrentApprovalAmount']/10 ** 5)
# <Axes: xlabel='CurrentApprovalAmount', ylabel='Density'>

# %%
df['CurrentApprovalAmount'].skew()
# Out:
# 1.9600225114723453

# %%
df['CurrentApprovalAmount'].kurt()
# Out:
# 3.816729637744085

# %%
#scatter plot ForgivenessAmount/CurrentApprovalAmount
var = 'ForgivenessAmount'
data = pd.concat([df['CurrentApprovalAmount'], df[var]], axis=1)
data.plot.scatter(x='CurrentApprovalAmount', y=var)
# Out:
# <Axes: xlabel='CurrentApprovalAmount', ylabel='ForgivenessAmount'>

# %%
matrix = df.corr(numeric_only = True)

# %%
##correlation matrix
matrix = df.corr(numeric_only = True)
ax = plt.subplots(figsize=(15, 11))
sms.heatmap(matrix, annot=True)
# Out:
# <Axes: >

# %%
df['']
